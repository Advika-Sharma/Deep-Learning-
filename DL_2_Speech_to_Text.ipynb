# %%
pip install SpeechRecognition pyaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr

# Initialize recognizer
recognizer = sr.Recognizer()

# Capture audio from microphone
with sr.Microphone() as source:
    print("🎙️ Say something...")
    audio = recognizer.listen(source)
    print("🔊 Recognizing...")

    try:
        text = recognizer.recognize_google(audio)
        print("📝 You said:", text)
    except sr.UnknownValueError:
        print("❌ Could not understand audio.")
    except sr.RequestError:
        print("⚠️ Could not request results; check your internet connection.")
# Out:
# 🎙️ Say something...
# 🔊 Recognizing...
# 📝 You said: hello welcome text to speech audio

# %%
Text to Speech
# Out:
#   Cell In[5], line 1
#     Text to Speech
#          ^
# SyntaxError: invalid syntax

# %%
pip install pyttsx3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3

# Initialize TTS engine
engine = pyttsx3.init()

# Input text
text = "Hello! This is Deep Learning Class"

# Speak the text
engine.say(text)
engine.runAndWait()

# %%
import pyttsx3

engine = pyttsx3.init()
engine.say("Hello Mani, welcome to text to speech using Python")
engine.runAndWait()

# %%
import pyttsx3

engine = pyttsx3.init()

while True:
    text = input("Enter text (type exit to stop): ")
    if text.lower() == "exit":
        break
    engine.say(text)
    engine.runAndWait()
# Out:
# Enter text (type exit to stop):  Hello

# %%
engine.setProperty('rate', 150)
engine.setProperty('volume', 0.9)

# %%
Video to Frames

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 262.6 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 281.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 324.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/39.0 MB 504.4 kB/s eta 0:01:18
#    ---------------------------------------- 0.1/39.0 MB 504.4 kB/s eta 0:01:18
# ...

# %%
import cv2
import os

# Path to the video file
video_path = "BigBuckbunny.mp4"
output_folder = "frames"

# Create folder to store frames
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Read video
cap = cv2.VideoCapture(video_path)
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break
    frame_name = f"{output_folder}/frame_{frame_count:04d}.jpg"
    cv2.imwrite(frame_name, frame)
    frame_count += 1

cap.release()
print(f"✅ {frame_count} frames saved in '{output_folder}' folder.")
# Out:
# ✅ 14315 frames saved in 'frames' folder.
